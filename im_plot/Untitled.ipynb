# %%
import scipy.io
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

# %%
mat = scipy.io.loadmat('data.mat')

# %%
mat.keys()
# Out:
# ['Dataset', '__version__', '__header__', '__globals__']

# %%
mat['Dataset'][0][0][7][:,0]
# Out:
# array([0.48448749, 0.48448749, 0.48452208, ..., 0.        , 0.        ,
#        0.        ])

# %%
fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.set_xlabel('X')
ax.set_ylabel('Y')
ax.set_zlabel('Z')
for i in range(72, mat['Dataset'].shape[1]):# - 72):
    p = mat['Dataset'][0][i][7]
    ax.scatter(p[:,0], p[:,1], p[:,2], 'r')
plt.show()
